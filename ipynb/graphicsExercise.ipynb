# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import random
import math

# %% [markdown]
# **(1a)** Produce a line plot using the data lists below.

# %%
ax = [0., 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
ay = [0.0, 0.25, 1.0, 2.25, 4.0, 6.25, 9.0]

# %% [markdown]
# **(1b)** Plot the data again but add axis labels and a title, say 'y-axis', 'x-axis' and 'Title'.

# %% [markdown]
# **(2)** Produce a basic scatter plot. Create two lists or arrays filled with 100 random numbers each from 0-1 and create a plot using the same simple axis and title labelling as shown above.

# %% [markdown]
# **(3)** Plot the function $y=\sin(x)^{2}$ for $-2\,\pi\leq{}x\leq{}2\,\pi$. Create an array of 1000 x-values and evaluate the function at those values when plotting it. Apply appropriate axis labels and a title.

# %% [markdown]
# **(4)** Plot a normalized Gaussian function according to $y=\frac{1}{\sigma\,\sqrt{2\,\pi}}\,\exp{}(-x^{2}/(2\,\sigma{})^{2})$ for $-10\leq{}x\leq{}10$ for three different values of the standard deviation $\sigma=1,\,1.5,\,2$. Apply appropriate axis labels and a title and number of points to plot.
#
# No need to create a Python function but re-calculate the y-function values with varying $\sigma$ values and re-plot on the same canvas.
#
# Multiple plotting curves on a single graphics requires a legend or labels or at least a caption explanation. Here, plot a legend for each of the three Gaussian curves.

# %% [markdown]
# **(5)** A molecule A reacts to form either molecules B or C with rate constants $k_{1}$ or $k_{2}$, respectively. That is $$A(t)=A_{0}\,e^{-(k_{1}+k_{2})\,t}$$ and $$B(t)=A_{0}\,\frac{k_{1}}{k_{1}+k_{2}}\,\left(1-e^{-(k_{1}+k_{2})\,t}\right)$$ and $$C(t)=A_{0}\,\frac{k_{2}}{k_{1}+k_{2}}\,\left(1-e^{-(k_{1}+k_{2})\,t}\right)$$.
#
# For a reaction with $k_{1}=300$ s$^{-1}$ and $k_{2}=100$ s$^{-1}$, plot concentrations of A, B and C against time given an initial concentration of $A_{0}=2$ mol dm$^{-3}$.
#
# Apply appropriate axis labels and a title and number of points to plot for time in an appropriate interval, starting at $t=0$. Draw the concentration for molecule A as a red line, for B as a green dashed line and for C as a cyan dotted line. Referring to solid, dashed and dotted lines would typically happen in a figure caption hence no legend.

# %% [markdown]
# Caption: Shown are concentrations for molecules A (solid line), B (dashed) and C (dotted) as a function of time.

# %% [markdown]
# **(6)** The seedhead of a sunflower may be modeled as follows. Number the n seeds $s=1,2,...,n$ and place each seed a distance $r=\sqrt{s}$ from the origin, rotated $\theta = 2\,\pi\,s / \phi$ from the x axis, where $\phi$ is some constant. The choice nature makes for $\phi$ is the golden ratio, $\phi =(1 + \sqrt{5})/2$, which maximizes the packing efficiency of the seeds as the seedhead grows.
#
# Plot the distance and angle variables as a function of seed number in a polar plot in order to create the shape of a sunflower seedhead. No axis labels or title are required.

# %% [markdown]
# **(7)** A histogram represents the distribution of data as a series of (usually vertical) bars with lengths in proportion to the number of data items falling into predefined ranges (known as bins). That is, the range of data values is divided into intervals and the histogram constructed by counting the number of data values in each interval.
#
# Create a histogram from 5000 random values, drawn from a Gaussian Normal distribution (mean at 0.0, width at 2.0). Request 20 bins and draw the histogram normalized (aka unity area). No axis labels or title are required.

# %% [markdown]
# **(8)** Make a plot with error bars. Gain more control about figures using the matplotlib figure directly. An error bar plot is a first example since it can require quite some flexibility (symmetric versus asymmetric errors, graphics options etc.).
#
# Use the data below for the plot, take symmetric errors for the x-values at $\triangle{}x=0.5$ and the asymmetric errors on the y-values as given. The row in that 2D array corresponds to the +error on y values, the second row to the -error. It therefore has to be a (2, n) array with n data values.
#
# Finish the code below to produce an error plot. Note that with a figure object, all graphics commands refer to the 'Axis' object, see starter lines below. No axis labels or title are required.

# %%
xval = np.array([0.3, 0.5, 0.7, 0.9])
yval = np.array([1.0, 2.0, 2.5, 3.9])
xerr = 0.5 # constant symetric error on x values
yerr = np.array([[0.1, 0.25, 0.5, 0.4], 
                [0.1, 0.15, 0.2, 0.0]]) # asymmetric y value errors

# %% [markdown]
# **(9)** Make four plots in two rows and two columns. Draw the Gauss curve with increasing standard deviation (see exercise 4) in each of the four plots, respectively, with $\sigma=0.5,\,1.0,\,1.5,\,3.0$. Use the fig, axis = plt.subplots() function. Put sensible labels on the axes, a title each and try to prevent them from overlapping with neighbouring plots.

# %% [markdown]
# **(10)** Contour plot: plot the electrostatic potential of an electric dipole according to $$V=\frac{q\,d}{4\,\pi\,\epsilon_{0}}\,\frac{x}{(x^{2}+y^{2})^{3/2}}$$ in the approximation of distance $d\ll{}x$. Constants and coordinate arrays are set up for you. Calculate the potential values as an array and draw it on a contour plot. You might wish to consider using custom made contour levels, say a few tens of levels between 1.0 and 1.0e5, in order to make the contours more visible. No axis labels or title are required here.

# %% [markdown]
# **(11)** Draw three arrays of 100 random numbers each. Consider each an array of coordinate values for x, y and z values respectively. Create a 3D scatter plot of these 100 points. No axis labels or title are required here.

# %% [markdown]
# **(12)** Calculate 400 by 400 points of a 2D Gaussian function without normalization in the intervals $-3\leq{}x,\,y\leq{}3$ and plot the function values in (a) a wireframe 3D plot and next to it, (b) a surface 3D plot. Pick a value of 40 when specifying stride values. Finer subdivisions would require smaller strides.
